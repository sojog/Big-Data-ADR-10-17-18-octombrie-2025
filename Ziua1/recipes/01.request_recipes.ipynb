# %% [markdown]
# # Requests este un modul pentru API (Application Programming Interface)

# %%
import requests

# %%
URL = "https://dummyjson.com/recipes"

# %%
response = requests.get(URL)

# %%
json_response = response.json()
json_response
# Out:
# {'recipes': [{'id': 1,
#    'name': 'Classic Margherita Pizza',
#    'ingredients': ['Pizza dough',
#     'Tomato sauce',
#     'Fresh mozzarella cheese',
#     'Fresh basil leaves',
#     'Olive oil',
#     'Salt and pepper to taste'],
#    'instructions': ['Preheat the oven to 475°F (245°C).',
#     'Roll out the pizza dough and spread tomato sauce evenly.',
#     'Top with slices of fresh mozzarella and fresh basil leaves.',
#     'Drizzle with olive oil and season with salt and pepper.',
#     'Bake in the preheated oven for 12-15 minutes or until the crust is golden brown.',
#     'Slice and serve hot.'],
#    'prepTimeMinutes': 20,
#    'cookTimeMinutes': 15,
#    'servings': 4,
#    'difficulty': 'Easy',
#    'cuisine': 'Italian',
#    'caloriesPerServing': 300,
#    'tags': ['Pizza', 'Italian'],
#    'userId': 166,
#    'image': 'https://cdn.dummyjson.com/recipe-images/1.webp',
#    'rating': 4.6,
#    'reviewCount': 98,
#    'mealType': ['Dinner']},
#   {'id': 2,
# ...

# %%
type(json_response)
# Out:
# dict

# %%
import pandas as pd

# %%
json_response.keys()
# Out:
# dict_keys(['recipes', 'total', 'skip', 'limit'])

# %%
recipes_df = pd.DataFrame(json_response["recipes"])
recipes_df
# Out:
#     id                               name  \
# 0    1           Classic Margherita Pizza
# 1    2                Vegetarian Stir-Fry
# 2    3             Chocolate Chip Cookies
# 3    4              Chicken Alfredo Pasta
# 4    5                Mango Salsa Chicken
# 5    6          Quinoa Salad with Avocado
# 6    7            Tomato Basil Bruschetta
# 7    8         Beef and Broccoli Stir-Fry
# 8    9                      Caprese Salad
# 9   10                Shrimp Scampi Pasta
# 10  11                    Chicken Biryani
# 11  12                     Chicken Karahi
# 12  13                         Aloo Keema
# 13  14                      Chapli Kebabs
# 14  15  Saag (Spinach) with Makki di Roti
# 15  16                Japanese Ramen Soup
# 16  17           Moroccan Chickpea Tagine
# 17  18                    Korean Bibimbap
# 18  19                     Greek Moussaka
# 19  20     Butter Chicken (Murgh Makhani)
# 20  21                   Thai Green Curry
# ...

# %%
recipes_df.count()
# Out:
# id                    30
# name                  30
# ingredients           30
# instructions          30
# prepTimeMinutes       30
# cookTimeMinutes       30
# servings              30
# difficulty            30
# cuisine               30
# caloriesPerServing    30
# tags                  30
# userId                30
# image                 30
# rating                30
# reviewCount           30
# mealType              30
# dtype: int64

# %%
recipes_df.head()
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
# 2   3    Chocolate Chip Cookies
# 3   4     Chicken Alfredo Pasta
# 4   5       Mango Salsa Chicken
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
# 2  [All-purpose flour, Butter, softened, Brown su...
# 3  [Fettuccine pasta, Chicken breast, sliced, Hea...
# 4  [Chicken thighs, Mango, diced, Red onion, fine...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
# 2  [Preheat the oven to 350°F (175°C)., In a bowl...               15
# 3  [Cook fettuccine pasta according to package in...               15
# 4  [Season chicken thighs with salt and pepper., ...               15
#
# ...

# %%
recipes_df.head(3)
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
# 2   3    Chocolate Chip Cookies
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
# 2  [All-purpose flour, Butter, softened, Brown su...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
# 2  [Preheat the oven to 350°F (175°C)., In a bowl...               15
#
#    cookTimeMinutes  servings difficulty   cuisine  caloriesPerServing  \
# 0               15         4       Easy   Italian                 300
# 1               20         3     Medium     Asian                 250
# 2               10        24       Easy  American                 150
#
#                             tags  userId  \
# ...

# %%
recipes_df.keys()
# Out:
# Index(['id', 'name', 'ingredients', 'instructions', 'prepTimeMinutes',
#        'cookTimeMinutes', 'servings', 'difficulty', 'cuisine',
#        'caloriesPerServing', 'tags', 'userId', 'image', 'rating',
#        'reviewCount', 'mealType'],
#       dtype='object')

# %% [markdown]
# # Selecta coloane

# %%
serie_nume = recipes_df["name"]
serie_nume
# Out:
# 0              Classic Margherita Pizza
# 1                   Vegetarian Stir-Fry
# 2                Chocolate Chip Cookies
# 3                 Chicken Alfredo Pasta
# 4                   Mango Salsa Chicken
# 5             Quinoa Salad with Avocado
# 6               Tomato Basil Bruschetta
# 7            Beef and Broccoli Stir-Fry
# 8                         Caprese Salad
# 9                   Shrimp Scampi Pasta
# 10                      Chicken Biryani
# 11                       Chicken Karahi
# 12                           Aloo Keema
# 13                        Chapli Kebabs
# 14    Saag (Spinach) with Makki di Roti
# 15                  Japanese Ramen Soup
# 16             Moroccan Chickpea Tagine
# 17                      Korean Bibimbap
# 18                       Greek Moussaka
# 19       Butter Chicken (Murgh Makhani)
# 20                     Thai Green Curry
# 21                          Mango Lassi
# 22                     Italian Tiramisu
# ...

# %%
name_df = recipes_df[["name"]]
name_df.head(2)
# Out:
#                        name
# 0  Classic Margherita Pizza
# 1       Vegetarian Stir-Fry

# %%
recipes_df.keys()
# Out:
# Index(['id', 'name', 'ingredients', 'instructions', 'prepTimeMinutes',
#        'cookTimeMinutes', 'servings', 'difficulty', 'cuisine',
#        'caloriesPerServing', 'tags', 'userId', 'image', 'rating',
#        'reviewCount', 'mealType'],
#       dtype='object')

# %%
short_recipes_df = recipes_df[['prepTimeMinutes',
       'cookTimeMinutes', 'servings', 'difficulty', 'cuisine',
       'caloriesPerServing', 'rating',
       'reviewCount']]
short_recipes_df.head()
# Out:
#    prepTimeMinutes  cookTimeMinutes  servings difficulty   cuisine  \
# 0               20               15         4       Easy   Italian
# 1               15               20         3     Medium     Asian
# 2               15               10        24       Easy  American
# 3               15               20         4     Medium   Italian
# 4               15               25         3       Easy   Mexican
#
#    caloriesPerServing  rating  reviewCount
# 0                 300     4.6           98
# 1                 250     4.7           26
# 2                 150     4.9           13
# 3                 500     4.9           82
# 4                 380     4.9           63

# %%
short_recipes_df.tail()
# Out:
#     prepTimeMinutes  cookTimeMinutes  servings difficulty    cuisine  \
# 25               15               15         4       Easy    Mexican
# 26               30               40         6     Medium    Russian
# 27               40               20         4     Medium     Indian
# 28               15               10         2       Easy   Lebanese
# 29                5                0         1       Easy  Brazilian
#
#     caloriesPerServing  rating  reviewCount
# 25                 180     4.6            2
# 26                 220     4.3           39
# 27                 320     4.4           96
# 28                 400     4.7           84
# 29                 150     4.4           55

# %% [markdown]
# # Pentru a lucra cu excel, pandas trebuie sa instaleze modulul openpyxl

# %% [markdown]
# pip install openpyxl

# %%
# short_recipes_df.to_excel("recipes.xlsx", index=False)
short_recipes_df.to_csv("recipes.csv", index=False)

# %%
short_recipes_df.describe()
# Out:
#        prepTimeMinutes  cookTimeMinutes   servings  caloriesPerServing  \
# count        30.000000        30.000000  30.000000           30.000000
# mean         21.500000        19.500000   4.366667          331.333333
# std           9.751216        12.821722   3.978245          122.776313
# min           5.000000         0.000000   1.000000          120.000000
# 25%          15.000000        11.250000   3.000000          227.500000
# 50%          20.000000        20.000000   4.000000          320.000000
# 75%          30.000000        28.750000   4.000000          415.000000
# max          45.000000        45.000000  24.000000          550.000000
#
#           rating  reviewCount
# count  30.000000    30.000000
# mean    4.616667    51.633333
# std     0.219848    30.673456
# min     4.200000     0.000000
# 25%     4.425000    27.000000
# 50%     4.600000    54.000000
# 75%     4.775000    81.000000
# max     5.000000    98.000000

# %%
short_recipes_df["difficulty"].unique()
# Out:
# array(['Easy', 'Medium'], dtype=object)

# %%
short_recipes_df["difficulty"].map({"Easy":0, "Medium":50})
# Out:
# 0      0
# 1     50
# 2      0
# 3     50
# 4      0
# 5      0
# 6      0
# 7     50
# 8      0
# 9     50
# 10    50
# 11     0
# 12    50
# 13    50
# 14    50
# 15    50
# 16     0
# 17    50
# 18    50
# 19    50
# 20    50
# 21     0
# 22    50
# 23     0
# 24     0
# 25     0
# 26    50
# 27    50
# 28     0
# 29     0
# Name: difficulty, dtype: int64

# %%
short_recipes_df
# Out:
#     prepTimeMinutes  cookTimeMinutes  servings difficulty        cuisine  \
# 0                20               15         4       Easy        Italian
# 1                15               20         3     Medium          Asian
# 2                15               10        24       Easy       American
# 3                15               20         4     Medium        Italian
# 4                15               25         3       Easy        Mexican
# 5                20               15         4       Easy  Mediterranean
# 6                15               10         6       Easy        Italian
# 7                20               15         4     Medium          Asian
# 8                10                0         2       Easy        Italian
# 9                15               20         3     Medium        Italian
# 10               30               45         6     Medium      Pakistani
# 11               20               30         4       Easy      Pakistani
# ...

# %%
short_recipes_df["difficulty_mapped"] = short_recipes_df["difficulty"].map({"Easy":0, "Medium":50})
short_recipes_df
# Out:
# /var/folders/3k/f_77v9pn1r94_xmvm2w3xgqr0000gn/T/ipykernel_25822/4223869589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_recipes_df["difficulty_mapped"] = short_recipes_df["difficulty"].map({"Easy":0, "Medium":50})
#     prepTimeMinutes  cookTimeMinutes  servings difficulty        cuisine  \
# 0                20               15         4       Easy        Italian
# 1                15               20         3     Medium          Asian
# 2                15               10        24       Easy       American
# 3                15               20         4     Medium        Italian
# 4                15               25         3       Easy        Mexican
# ...

# %%
short_recipes_df.dtypes
# Out:
# prepTimeMinutes         int64
# cookTimeMinutes         int64
# servings                int64
# difficulty             object
# cuisine                object
# caloriesPerServing      int64
# rating                float64
# reviewCount             int64
# difficulty_mapped       int64
# dtype: object

# %%
short_recipes_df.describe()
# Out:
#        prepTimeMinutes  cookTimeMinutes   servings  caloriesPerServing  \
# count        30.000000        30.000000  30.000000           30.000000
# mean         21.500000        19.500000   4.366667          331.333333
# std           9.751216        12.821722   3.978245          122.776313
# min           5.000000         0.000000   1.000000          120.000000
# 25%          15.000000        11.250000   3.000000          227.500000
# 50%          20.000000        20.000000   4.000000          320.000000
# 75%          30.000000        28.750000   4.000000          415.000000
# max          45.000000        45.000000  24.000000          550.000000
#
#           rating  reviewCount  difficulty_mapped
# count  30.000000    30.000000          30.000000
# mean    4.616667    51.633333          26.666667
# std     0.219848    30.673456          25.370813
# min     4.200000     0.000000           0.000000
# 25%     4.425000    27.000000           0.000000
# ...

# %%
short_recipes_df.head()
# Out:
#    prepTimeMinutes  cookTimeMinutes  servings difficulty   cuisine  \
# 0               20               15         4       Easy   Italian
# 1               15               20         3     Medium     Asian
# 2               15               10        24       Easy  American
# 3               15               20         4     Medium   Italian
# 4               15               25         3       Easy   Mexican
#
#    caloriesPerServing  rating  reviewCount  difficulty_mapped
# 0                 300     4.6           98                  0
# 1                 250     4.7           26                 50
# 2                 150     4.9           13                  0
# 3                 500     4.9           82                 50
# 4                 380     4.9           63                  0

# %%
preptimes = short_recipes_df["cookTimeMinutes"].unique()
preptimes.sort()
preptimes
# Out:
# array([ 0, 10, 15, 20, 25, 30, 35, 40, 45])

# %% [markdown]
# # Filtrarea dupa preptime

# %%
short_recipes_df["cookTimeMinutes"] > 26
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13    False
# 14     True
# 15    False
# 16     True
# 17    False
# 18     True
# 19    False
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
# Name: cookTimeMinutes, dtype: bool

# %%
cook_time_filter = short_recipes_df["cookTimeMinutes"] > 26
short_recipes_df[cook_time_filter]
# Out:
#     prepTimeMinutes  cookTimeMinutes  servings difficulty    cuisine  \
# 10               30               45         6     Medium  Pakistani
# 11               20               30         4       Easy  Pakistani
# 12               25               35         5     Medium  Pakistani
# 14               40               30         3     Medium  Pakistani
# 16               15               30         4       Easy   Moroccan
# 18               45               45         6     Medium      Greek
# 20               20               30         4     Medium       Thai
# 26               30               40         6     Medium    Russian
#
#     caloriesPerServing  rating  reviewCount  difficulty_mapped
# 10                 550     5.0           32                 50
# 11                 420     4.8           68                  0
# 12                 380     4.6           53                 50
# 14                 280     4.3           86                 50
# ...

# %%
short_recipes_df[short_recipes_df["cookTimeMinutes"] > 26]
# Out:
#     prepTimeMinutes  cookTimeMinutes  servings difficulty    cuisine  \
# 10               30               45         6     Medium  Pakistani
# 11               20               30         4       Easy  Pakistani
# 12               25               35         5     Medium  Pakistani
# 14               40               30         3     Medium  Pakistani
# 16               15               30         4       Easy   Moroccan
# 18               45               45         6     Medium      Greek
# 20               20               30         4     Medium       Thai
# 26               30               40         6     Medium    Russian
#
#     caloriesPerServing  rating  reviewCount  difficulty_mapped
# 10                 550     5.0           32                 50
# 11                 420     4.8           68                  0
# 12                 380     4.6           53                 50
# 14                 280     4.3           86                 50
# ...

# %%
short_recipes_df["caloriesPerServing"].min(), short_recipes_df["caloriesPerServing"].max()
# Out:
# (np.int64(120), np.int64(550))

# %%
short_recipes_df[short_recipes_df["caloriesPerServing"] == short_recipes_df["caloriesPerServing"].max()]
# Out:
#     prepTimeMinutes  cookTimeMinutes  servings difficulty    cuisine  \
# 10               30               45         6     Medium  Pakistani
# 17               30               20         2     Medium     Korean
#
#     caloriesPerServing  rating  reviewCount  difficulty_mapped
# 10                 550     5.0           32                 50
# 17                 550     4.9           56                 50

# %%
recipes_df[recipes_df["caloriesPerServing"] == recipes_df["caloriesPerServing"].max()]
# Out:
#     id             name                                        ingredients  \
# 10  11  Chicken Biryani  [Basmati rice, Chicken, cut into pieces, Onion...
# 17  18  Korean Bibimbap  [Cooked white rice, Beef bulgogi (marinated an...
#
#                                          instructions  prepTimeMinutes  \
# 10  [Marinate chicken with yogurt, ginger-garlic p...               30
# 17  [Arrange cooked white rice in a bowl., Top wit...               30
#
#     cookTimeMinutes  servings difficulty    cuisine  caloriesPerServing  \
# 10               45         6     Medium  Pakistani                 550
# 17               20         2     Medium     Korean                 550
#
#                                                  tags  userId  \
# 10  [Biryani, Chicken, Main course, Indian, Pakist...     133
# 17                           [Bibimbap, Korean, Rice]     121
#
#                                               image  rating  reviewCount  \
# ...

# %%
short_recipes_df.head(3)
# Out:
#    prepTimeMinutes  cookTimeMinutes  servings difficulty   cuisine  \
# 0               20               15         4       Easy   Italian
# 1               15               20         3     Medium     Asian
# 2               15               10        24       Easy  American
#
#    caloriesPerServing  rating  reviewCount  difficulty_mapped
# 0                 300     4.6           98                  0
# 1                 250     4.7           26                 50
# 2                 150     4.9           13                  0

# %%
short_recipes_df["servings"].unique()
# Out:
# array([ 4,  3, 24,  6,  2,  5,  1])

# %%
short_recipes_df.groupby("servings").agg('count')
# Out:
#           prepTimeMinutes  cookTimeMinutes  difficulty  cuisine  \
# servings
# 1                       2                2           2        2
# 2                       5                5           5        5
# 3                       4                4           4        4
# 4                      12               12          12       12
# 5                       1                1           1        1
# 6                       5                5           5        5
# 24                      1                1           1        1
#
#           caloriesPerServing  rating  reviewCount  difficulty_mapped
# servings
# 1                          2       2            2                  2
# 2                          5       5            5                  5
# 3                          4       4            4                  4
# 4                         12      12           12                 12
# 5                          1       1            1                  1
# ...

# %%
recipes_df.groupby("servings").agg('count')["name"]
# Out:
# servings
# 1      2
# 2      5
# 3      4
# 4     12
# 5      1
# 6      5
# 24     1
# Name: name, dtype: int64

# %%
short_recipes_df.head(2)
# Out:
#    prepTimeMinutes  cookTimeMinutes  servings difficulty  cuisine  \
# 0               20               15         4       Easy  Italian
# 1               15               20         3     Medium    Asian
#
#    caloriesPerServing  rating  reviewCount  difficulty_mapped
# 0                 300     4.6           98                  0
# 1                 250     4.7           26                 50

# %%
short_recipes_df["name"] = recipes_df["name"]
short_recipes_df.head(2)
# Out:
# /var/folders/3k/f_77v9pn1r94_xmvm2w3xgqr0000gn/T/ipykernel_25822/2515062993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_recipes_df["name"] = recipes_df["name"]
#    prepTimeMinutes  cookTimeMinutes  servings difficulty  cuisine  \
# 0               20               15         4       Easy  Italian
# 1               15               20         3     Medium    Asian
#
#    caloriesPerServing  rating  reviewCount  difficulty_mapped  \
# 0                 300     4.6           98                  0
# 1                 250     4.7           26                 50
#
#                        name
# 0  Classic Margherita Pizza
# 1       Vegetarian Stir-Fry

# %%
retete_noi = {
    "name" : ["Mici"],
    "prepTimeMinutes" : [30],
    "cookTimeMinutes" : [32],
    "servings" : [3],	
    "difficulty" : ["Easy"],
    "cuisine" : [ "Romanian"],
    "caloriesPerServing" : [32],
    "rating" : [5.0],
    "reviewCount" : [32],
    "difficulty_mapped" : [50]
}

# %%
new_recipes_df = pd.DataFrame(retete_noi)
new_recipes_df
# Out:
#    name  prepTimeMinutes  cookTimeMinutes  servings difficulty   cuisine  \
# 0  Mici               30               32         3       Easy  Romanian
#
#    caloriesPerServing  rating  reviewCount  difficulty_mapped
# 0                  32     5.0           32                 50

# %%
result_df = pd.concat([new_recipes_df, short_recipes_df])
result_df.head(4)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0                      Mici               30               32         3
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
# 2    Chocolate Chip Cookies               15               10        24
#
#   difficulty   cuisine  caloriesPerServing  rating  reviewCount  \
# 0       Easy  Romanian                  32     5.0           32
# 0       Easy   Italian                 300     4.6           98
# 1     Medium     Asian                 250     4.7           26
# 2       Easy  American                 150     4.9           13
#
#    difficulty_mapped
# 0                 50
# 0                  0
# 1                 50
# 2                  0

# %%
result_df = pd.concat([new_recipes_df, short_recipes_df]).reset_index()
result_df.head(4)
# Out:
#    index                      name  prepTimeMinutes  cookTimeMinutes  \
# 0      0                      Mici               30               32
# 1      0  Classic Margherita Pizza               20               15
# 2      1       Vegetarian Stir-Fry               15               20
# 3      2    Chocolate Chip Cookies               15               10
#
#    servings difficulty   cuisine  caloriesPerServing  rating  reviewCount  \
# 0         3       Easy  Romanian                  32     5.0           32
# 1         4       Easy   Italian                 300     4.6           98
# 2         3     Medium     Asian                 250     4.7           26
# 3        24       Easy  American                 150     4.9           13
#
#    difficulty_mapped
# 0                 50
# 1                  0
# 2                 50
# 3                  0

# %%
result_df = pd.concat([new_recipes_df, short_recipes_df]).reset_index(drop=True)
result_df.head(4)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0                      Mici               30               32         3
# 1  Classic Margherita Pizza               20               15         4
# 2       Vegetarian Stir-Fry               15               20         3
# 3    Chocolate Chip Cookies               15               10        24
#
#   difficulty   cuisine  caloriesPerServing  rating  reviewCount  \
# 0       Easy  Romanian                  32     5.0           32
# 1       Easy   Italian                 300     4.6           98
# 2     Medium     Asian                 250     4.7           26
# 3       Easy  American                 150     4.9           13
#
#    difficulty_mapped
# 0                 50
# 1                  0
# 2                 50
# 3                  0

# %%
result_df["prepTimeMinutes"][0]
# Out:
# np.int64(30)

# %%
type(result_df["prepTimeMinutes"][0])
# Out:
# numpy.int64

# %%
result_df["prepTimeMinutes"].plot()
# Out:
# <Axes: >
