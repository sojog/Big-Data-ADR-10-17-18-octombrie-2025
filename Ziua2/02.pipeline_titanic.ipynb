# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Citim cele 3 db

# %%
train_df = pd.read_csv("database/train.csv", index_col='PassengerId')
len(train_df.keys())
# Out:
# 11

# %%
test_df = pd.read_csv("database/test.csv", index_col='PassengerId')
len(test_df.keys())
# Out:
# 10

# %%
test_results_df = pd.read_csv("database/gender_submission.csv", index_col='PassengerId')
test_results_df.keys()
# Out:
# Index(['Survived'], dtype='object')

# %%
combined_df = pd.concat([test_df, test_results_df], axis=1)
combined_df.shape
# Out:
# (418, 11)

# %%
test_results_df.shape, test_df.shape
# Out:
# ((418, 1), (418, 10))

# %%
combined_df
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
# train_df["Gender"] = train_df["Sex"].map({"female": 0, "male": 1})
# combined_df["Gender"] = combined_df["Sex"].map({"female": 0, "male": 1})

# %%
def transform_gender(df):
    df["Sex"] = df["Sex"].map({"female": 0, "male": 1})
    return df

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def label_encode_column(df, column_name):
    df[column_name] = LabelEncoder().fit_transform(df[column_name] )
    return df

# %%
def drop_column(df, column_name):
    df = df.drop(column_name, axis=1)
    return df

# %%
# Versiunea 1 - clasica
# train_df = transform_gender(train_df)
# train_df.head(2)

# %%
# Versiunea 2 - pipeline
train_df.pipe(label_encode_column, "Sex").pipe(label_encode_column, "Embarked").pipe(drop_column, "Name").pipe(drop_column, "Ticket")
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 1                   0       3    1  22.0      1      0   7.2500   NaN
# 2                   1       1    0  38.0      1      0  71.2833   C85
# 3                   1       3    0  26.0      0      0   7.9250   NaN
# 4                   1       1    0  35.0      1      0  53.1000  C123
# 5                   0       3    1  35.0      0      0   8.0500   NaN
# ...               ...     ...  ...   ...    ...    ...      ...   ...
# 887                 0       2    1  27.0      0      0  13.0000   NaN
# 888                 1       1    0  19.0      0      0  30.0000   B42
# 889                 0       3    0   NaN      1      2  23.4500   NaN
# 890                 1       1    1  26.0      0      0  30.0000  C148
# 891                 0       3    1  32.0      0      0   7.7500   NaN
#
#              Embarked
# PassengerId
# 1                   2
# 2                   0
# 3                   2
# ...

# %%
combined_df.pipe(label_encode_column, "Sex").pipe(label_encode_column, "Embarked").pipe(drop_column, "Name").pipe(drop_column, "Ticket")
# Out:
#              Pclass  Sex   Age  SibSp  Parch      Fare Cabin  Embarked  \
# PassengerId
# 892               3    1  34.5      0      0    7.8292   NaN         1
# 893               3    0  47.0      1      0    7.0000   NaN         2
# 894               2    1  62.0      0      0    9.6875   NaN         1
# 895               3    1  27.0      0      0    8.6625   NaN         2
# 896               3    0  22.0      1      1   12.2875   NaN         2
# ...             ...  ...   ...    ...    ...       ...   ...       ...
# 1305              3    1   NaN      0      0    8.0500   NaN         2
# 1306              1    0  39.0      0      0  108.9000  C105         0
# 1307              3    1  38.5      0      0    7.2500   NaN         2
# 1308              3    1   NaN      0      0    8.0500   NaN         2
# 1309              3    1   NaN      1      1   22.3583   NaN         0
#
#              Survived
# PassengerId
# 892                 0
# 893                 1
# ...
