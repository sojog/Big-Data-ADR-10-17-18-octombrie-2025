# %% [markdown]
# # pip install pandas
# # pip install matplotlib
# # pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("database/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df = pd.read_csv("database/train.csv", index_col='PassengerId')
df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
df.keys(), len(df.keys())
# Out:
# (Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#         'Fare', 'Cabin', 'Embarked'],
#        dtype='object'),
#  11)

# %%
df.describe(), len(df.describe().keys())
# Out:
# (         Survived      Pclass         Age       SibSp       Parch        Fare
#  count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
#  mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
#  std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
#  min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
#  25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
#  50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
#  75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
#  max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200,
#  6)

# %%
# Survival	Survival	0 = No, 1 = Yes
# pclass	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# #sex	Sex	
# Age	Age in years	
# sibsp	# of siblings / spouses aboard the Titanic	
# parch	# of parents / children aboard the Titanic	
# ticket	Ticket number	
# fare	Passenger fare	
# cabin	Cabin number	
# embarked	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = SouthamptonS

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
df["Sex"].unique(), df["Sex"].nunique()
# Out:
# (array(['male', 'female'], dtype=object), 2)

# %%
df["Gender"] = df["Sex"] == "male"
df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked  Gender
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S    True
# 2                1      0   PC 17599  71.2833   C85        C   False

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# Gender         bool
# dtype: object

# %%
df["Gender"] = df["Sex"].map({"female": 0, "male": 1})
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  Gender
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S       1
# 2                1      0          PC 17599  71.2833   C85        C       0
# ...

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#            Gender
# count  891.000000
# mean     0.647587
# std      0.477990
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
df = df.drop("Sex", axis=1)
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 3                                       Heikkinen, Miss. Laina  26.0      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 5                                     Allen, Mr. William Henry  35.0      0
#
#              Parch            Ticket     Fare Cabin Embarked  Gender
# PassengerId
# 1                0         A/5 21171   7.2500   NaN        S       1
# 2                0          PC 17599  71.2833   C85        C       0
# 3                0  STON/O2. 3101282   7.9250   NaN        S       0
# ...

# %%
df["Name"].nunique()
# Out:
# 891

# %%
df.keys()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare',
#        'Cabin', 'Embarked', 'Gender'],
#       dtype='object')

# %%
for key in ('Pclass', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'):
    print("key: ", key, df[key].nunique())
# Out:
# key:  Pclass 3
# key:  Parch 7
# key:  Ticket 681
# key:  Fare 248
# key:  Cabin 147
# key:  Embarked 3

# %%
df["Embarked"] .unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Embarked"].count()
# Out:
# np.int64(889)

# %%
# cate sunt nule
df["Embarked"].isnull().sum()
# Out:
# np.int64(2)

# %%
df["Embarked"] = df["Embarked"].map({'S':3, 'C':1, 'Q':2, 'nan':0})
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 3                                       Heikkinen, Miss. Laina  26.0      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 5                                     Allen, Mr. William Henry  35.0      0
#
#              Parch            Ticket     Fare Cabin  Embarked  Gender
# PassengerId
# 1                0         A/5 21171   7.2500   NaN       3.0       1
# 2                0          PC 17599  71.2833   C85       1.0       0
# 3                0  STON/O2. 3101282   7.9250   NaN       3.0       0
# ...

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked    float64
# Gender        int64
# dtype: object

# %%
df["Cabin"].unique(), df["Cabin"].nunique()
# Out:
# (array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#         'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#         'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#         'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#         'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#         'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#         'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#         'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#         'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#         'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#         'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#         'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#         'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
set([str(x)[0] for x in  df["Cabin"].unique()])
# Out:
# {'A', 'B', 'C', 'D', 'E', 'F', 'G', 'T', 'n'}

# %%
df["Cabin_LETTER"] = df["Cabin"].astype(np.str_).str[0]
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 3                                       Heikkinen, Miss. Laina  26.0      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 5                                     Allen, Mr. William Henry  35.0      0
#
#              Parch            Ticket     Fare Cabin  Embarked  Gender  \
# PassengerId
# 1                0         A/5 21171   7.2500   NaN       3.0       1
# 2                0          PC 17599  71.2833   C85       1.0       0
# ...

# %%
df["Cabin_LETTER"] = df["Cabin_LETTER"].map({'A':1, 'B':2, 'C':3, 'D':4, 'E':5, 'F':6, 'G':7, 'T':8, 'n':0})
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 3                                       Heikkinen, Miss. Laina  26.0      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 5                                     Allen, Mr. William Henry  35.0      0
# ...                                                        ...   ...    ...
# ...

# %%
plt.scatter(df["Gender"], df["Age"], c=df["Survived"])

# %%
plt.scatter(df["Age"], df["Gender"], c=df["Survived"])
plt.xlabel("Age")
plt.ylabel ("Gender. 1-Male, 0-Female")
plt.legend(df["Survived"])

# %%
plt.rcParams["figure.figsize"] # default [6.4, 4.8]
# Out:
# [20.0, 4.8]

# %%
plt.rcParams["figure.figsize"]  = [20, 4.8]

# %%
plt.scatter(df["Age"], df["Gender"], c=df["Survived"]);
plt.xlabel("Age")
plt.ylabel ("Gender. 1-Male, 0-Female");

# %%
df.plot.scatter(x="Age", y="Gender", c="Survived");

# %%
df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
#
#              Parch     Ticket     Fare Cabin  Embarked  Gender  Cabin_LETTER
# PassengerId
# 1                0  A/5 21171   7.2500   NaN       3.0       1             0
# 2                0   PC 17599  71.2833   C85       1.0       0             3

# %%
df.plot.scatter(x="Age", y="Embarked", c="Survived");

# %%
df.keys()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare',
#        'Cabin', 'Embarked', 'Gender', 'Cabin_LETTER'],
#       dtype='object')

# %%
numbers_only_df = df[        ['Survived', 'Pclass',  'Age', 'SibSp', 'Parch',  'Fare',
      'Embarked', 'Gender', 'Cabin_LETTER']     ]
numbers_only_df.head(2)
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  Embarked  Gender  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500       3.0       1
# 2                   1       1  38.0      1      0  71.2833       1.0       0
#
#              Cabin_LETTER
# PassengerId
# 1                       0
# 2                       3

# %%
numbers_only_df.dtypes
# Out:
# Survived          int64
# Pclass            int64
# Age             float64
# SibSp             int64
# Parch             int64
# Fare            float64
# Embarked        float64
# Gender            int64
# Cabin_LETTER      int64
# dtype: object

# %%
numbers_only_df.corr()
# Out:
#               Survived    Pclass       Age     SibSp     Parch      Fare  \
# Survived      1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass       -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age          -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp        -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch         0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare          0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# Embarked     -0.169718  0.164681 -0.032565  0.068900  0.040449 -0.226311
# Gender       -0.543351  0.131900  0.093254 -0.114631 -0.245489 -0.182333
# Cabin_LETTER  0.287944 -0.570691  0.179643 -0.031973  0.037621  0.337525
#
#               Embarked    Gender  Cabin_LETTER
# Survived     -0.169718 -0.543351      0.287944
# Pclass        0.164681  0.131900     -0.570691
# Age          -0.032565  0.093254      0.179643
# SibSp         0.068900 -0.114631     -0.031973
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(numbers_only_df.corr())
# Out:
# <Axes: >

# %%
plt.rcParams["figure.figsize"]  = [6.4, 4.8]

# %%
sns.heatmap(numbers_only_df.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(numbers_only_df.corr(), cmap="coolwarm")
# Out:
# <Axes: >

# %%
old_than_15_df = numbers_only_df[numbers_only_df["Age"] > 15]

sns.heatmap(old_than_15_df.corr(), cmap="coolwarm")
# Out:
# <Axes: >
