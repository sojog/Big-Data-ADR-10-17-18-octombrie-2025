# %%
import pandas as pd

# %%
df = pd.read_csv("movie.csv", index_col = "movieId")
df
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
# ...                                     ...
# 131254         Kein Bund für's Leben (2007)
# 131256        Feuer, Eis & Dosenbier (2002)
# 131258                   The Pirates (2014)
# 131260                  Rentun Ruusu (2001)
# 131262                     Innocence (2014)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# ...                                              ...
# ...

# %%
df["year"] = df["title"].str[-5:-1]
df["title"] = df["title"].str[:-7]
df
# Out:
#                                title  \
# movieId
# 1                          Toy Story
# 2                            Jumanji
# 3                   Grumpier Old Men
# 4                  Waiting to Exhale
# 5        Father of the Bride Part II
# ...                              ...
# 131254         Kein Bund für's Leben
# 131256        Feuer, Eis & Dosenbier
# 131258                   The Pirates
# 131260                  Rentun Ruusu
# 131262                     Innocence
#
#                                               genres  year
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy  1995
# 2                         Adventure|Children|Fantasy  1995
# 3                                     Comedy|Romance  1995
# 4                               Comedy|Drama|Romance  1995
# 5                                             Comedy  1995
# ...                                              ...   ...
# 131254                                        Comedy  2007
# ...

# %%
df.to_csv("movies_year.csv")
